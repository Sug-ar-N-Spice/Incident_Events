# %%
import pandas as pd
import numpy as np

# Load the CSV file into a DataFrame
df = pd.read_csv('/Users/simonponce/Desktop/Class Project 08_2024/Ty Incident_Management/Incident_Management/incident_event_log.csv')

# %%
df.head()
# Out:
#        number incident_state  active  reassignment_count  reopen_count  \
# 0  INC0000045            New    True                   0             0
# 1  INC0000045       Resolved    True                   0             0
# 2  INC0000045       Resolved    True                   0             0
# 3  INC0000045         Closed   False                   0             0
# 4  INC0000047            New    True                   0             0
#
#    sys_mod_count  made_sla    caller_id       opened_by        opened_at  ...  \
# 0              0      True  Caller 2403    Opened by  8  29/2/2016 01:16  ...
# 1              2      True  Caller 2403    Opened by  8  29/2/2016 01:16  ...
# 2              3      True  Caller 2403    Opened by  8  29/2/2016 01:16  ...
# 3              4      True  Caller 2403    Opened by  8  29/2/2016 01:16  ...
# 4              0      True  Caller 2403  Opened by  397  29/2/2016 04:40  ...
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 141712 entries, 0 to 141711
# Data columns (total 36 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   number                   141712 non-null  object
#  1   incident_state           141712 non-null  object
#  2   active                   141712 non-null  bool
#  3   reassignment_count       141712 non-null  int64
#  4   reopen_count             141712 non-null  int64
#  5   sys_mod_count            141712 non-null  int64
#  6   made_sla                 141712 non-null  bool
#  7   caller_id                141712 non-null  object
#  8   opened_by                141712 non-null  object
#  9   opened_at                141712 non-null  object
#  10  sys_created_by           141712 non-null  object
#  11  sys_created_at           141712 non-null  object
#  12  sys_updated_by           141712 non-null  object
# ...

# %%
df_incident = df.replace('?',np.nan)

# %%
df_incident
# Out:
#             number incident_state  active  reassignment_count  reopen_count  \
# 0       INC0000045            New    True                   0             0
# 1       INC0000045       Resolved    True                   0             0
# 2       INC0000045       Resolved    True                   0             0
# 3       INC0000045         Closed   False                   0             0
# 4       INC0000047            New    True                   0             0
# ...            ...            ...     ...                 ...           ...
# 141707  INC0120835         Closed   False                   1             0
# 141708  INC0121064         Active    True                   0             0
# 141709  INC0121064         Active    True                   1             0
# 141710  INC0121064       Resolved    True                   1             0
# 141711  INC0121064         Closed   False                   1             0
#
# ...

# %%
df_incident = df.replace('?',np.nan)

# %%
df_incident = df_incident.drop(columns=['number'])
df_incident = df_incident.drop(columns=['incident_state'])
df_incident
# Out:
#         active  reassignment_count  reopen_count  sys_mod_count  made_sla  \
# 0         True                   0             0              0      True
# 1         True                   0             0              2      True
# 2         True                   0             0              3      True
# 3        False                   0             0              4      True
# 4         True                   0             0              0      True
# ...        ...                 ...           ...            ...       ...
# 141707   False                   1             0              4      True
# 141708    True                   0             0              0      True
# 141709    True                   1             0              1      True
# 141710    True                   1             0              2      True
# 141711   False                   1             0              3      True
#
#           caller_id       opened_by        opened_at  sys_created_by  \
# ...

# %%
# Sean messing around
def grab_number(value):
    if value == "?":
        return -1
    return value.split(" ")[1]
# df['caller_id'].str.split(" ").apply(lambda x: x[0]).value_counts()
df['caller_id'].apply(grab_number).astype(int)
# Out:
# 0         2403
# 1         2403
# 2         2403
# 3         2403
# 4         2403
#           ...
# 141707     116
# 141708     116
# 141709     116
# 141710     116
# 141711     116
# Name: caller_id, Length: 141712, dtype: int64

# %%
df_incident['opened_at'] = pd.to_datetime(df_incident['opened_at'])
df_incident['year'] = df_incident['opened_at'].dt.year
df_incident['month'] = df_incident['opened_at'].dt.month
df_incident['day'] = df_incident['opened_at'].dt.day
df_incident['hour'] = df_incident['opened_at'].dt.hour
df_incident['minute'] = df_incident['opened_at'].dt.minute
df_incident['second'] = df_incident['opened_at'].dt.second

df_incident
# Out:
# /var/folders/yv/1k6t_v4x7798wpq87ddlnmjw0000gn/T/ipykernel_1186/2980537453.py:1: UserWarning: Parsing dates in %d/%m/%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df_incident['opened_at'] = pd.to_datetime(df_incident['opened_at'])
#         active  reassignment_count  reopen_count  sys_mod_count  made_sla  \
# 0         True                   0             0              0      True
# 1         True                   0             0              2      True
# 2         True                   0             0              3      True
# 3        False                   0             0              4      True
# 4         True                   0             0              0      True
# ...        ...                 ...           ...            ...       ...
# 141707   False                   1             0              4      True
# ...

# %%
# Sean messing around
def grab_number(value):
    if value == "?":
        return -1
    return value.split(" ")[1]
# df['caller_id'].str.split(" ").apply(lambda x: x[0]).value_counts()
df['caller_id'].apply(grab_number).astype(int)
# Out:
# 0         2403
# 1         2403
# 2         2403
# 3         2403
# 4         2403
#           ...
# 141707     116
# 141708     116
# 141709     116
# 141710     116
# 141711     116
# Name: caller_id, Length: 141712, dtype: int64

# %%
# Splitting the 'opened_at', 'resolved_at', and 'closed_at' dates into separate Day, Month, and Year columns
# For 'opened_at'
df_incident['opened_day'] = pd.to_datetime(df_incident['opened_at'], format="%d/%m/%Y %H:%M", dayfirst=True).dt.day
df_incident['opened_month'] = pd.to_datetime(df_incident['opened_at'], format="%d/%m/%Y %H:%M", dayfirst=True).dt.month
df_incident['opened_year'] = pd.to_datetime(df_incident['opened_at'], format="%d/%m/%Y %H:%M", dayfirst=True).dt.year
# For 'resolved_at'
df_incident['resolved_day'] = pd.to_datetime(df_incident['resolved_at'], format="%d/%m/%Y %H:%M", dayfirst=True).dt.day
df_incident['resolved_month'] = pd.to_datetime(df_incident['resolved_at'], format="%d/%m/%Y %H:%M", dayfirst=True).dt.month
df_incident['resolved_year'] = pd.to_datetime(df_incident['resolved_at'], format="%d/%m/%Y %H:%M", dayfirst=True).dt.year
# For 'closed_at'
df_incident['closed_day'] = pd.to_datetime(df_incident['closed_at'], format="%d/%m/%Y %H:%M", dayfirst=True).dt.day
df_incident['closed_month'] = pd.to_datetime(df_incident['closed_at'], format="%d/%m/%Y %H:%M", dayfirst=True).dt.month
df_incident['closed_year'] = pd.to_datetime(df_incident['closed_at'], format="%d/%m/%Y %H:%M", dayfirst=True).dt.year

# Display the first few rows of the new columns to verify the splitting
df_incident[['opened_day', 'opened_month', 'opened_year',
               'resolved_day', 'resolved_month', 'resolved_year',
               'closed_day', 'closed_month', 'closed_year']].head()
# Out:
#    opened_day  opened_month  opened_year  resolved_day  resolved_month  \
# 0          29             2         2016          29.0             2.0
# 1          29             2         2016          29.0             2.0
# 2          29             2         2016          29.0             2.0
# 3          29             2         2016          29.0             2.0
# 4          29             2         2016           1.0             3.0
#
#    resolved_year  closed_day  closed_month  closed_year
# 0         2016.0           5             3         2016
# 1         2016.0           5             3         2016
# 2         2016.0           5             3         2016
# 3         2016.0           5             3         2016
# 4         2016.0           6             3         2016

# %%
# Splitting the 'opened_at', 'resolved_at', and 'closed_at' dates into separate Day, Month, and Year columns
# For 'opened_at'
df_incident['opened_day'] = pd.to_datetime(df_incident['opened_at']).dt.day
df_incident['opened_month'] = pd.to_datetime(df_incident['opened_at']).dt.month_name()
df_incident['opened_year'] = pd.to_datetime(df_incident['opened_at']).dt.year
# For 'resolved_at'
df_incident['resolved_day'] = pd.to_datetime(df_incident['resolved_at']).dt.day
df_incident['resolved_month'] = pd.to_datetime(df_incident['resolved_at']).dt.month_name()
df_incident['resolved_year'] = pd.to_datetime(df_incident['resolved_at']).dt.year
# For 'closed_at'
df_incident['closed_day'] = pd.to_datetime(df_incident['closed_at']).dt.day
df_incident['closed_month'] = pd.to_datetime(df_incident['closed_at']).dt.month_name()
df_incident['closed_year'] = pd.to_datetime(df_incident['closed_at']).dt.year
# Display the first few rows of the new columns to verify the splitting
df_incident[['opened_day', 'opened_month', 'opened_year',
               'resolved_day', 'resolved_month', 'resolved_year',
               'closed_day', 'closed_month', 'closed_year']].head()
# Out:
# /var/folders/yv/1k6t_v4x7798wpq87ddlnmjw0000gn/T/ipykernel_1186/1324048862.py:7: UserWarning: Parsing dates in %d/%m/%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df_incident['resolved_day'] = pd.to_datetime(df_incident['resolved_at']).dt.day
# /var/folders/yv/1k6t_v4x7798wpq87ddlnmjw0000gn/T/ipykernel_1186/1324048862.py:8: UserWarning: Parsing dates in %d/%m/%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df_incident['resolved_month'] = pd.to_datetime(df_incident['resolved_at']).dt.month_name()
# /var/folders/yv/1k6t_v4x7798wpq87ddlnmjw0000gn/T/ipykernel_1186/1324048862.py:9: UserWarning: Parsing dates in %d/%m/%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
# ...

# %%
df_incident['closed_month'] = pd.to_datetime(df_incident['closed_at'], format='%d/%m/%Y %H:%M').dt.month

# %%
# Convert the month names back to integers (1 for January, 2 for February, etc.)
df_incident['opened_month'] = pd.to_datetime(df_incident['opened_at']).dt.month
df_incident['resolved_month'] = pd.to_datetime(df_incident['resolved_at']).dt.month
df_incident['closed_month'] = pd.to_datetime(df_incident['closed_at']).dt.month
# Display the first few rows to confirm the conversion
df_incident[['opened_month', 'resolved_month', 'closed_month']].head()
#fixing ? in the resolved_at column
df_incident['resolved_month'] = pd.to_datetime(df_incident['resolved_at'], format='%d/%m/%Y %H:%M', errors='coerce').dt.month
# Out:
# /var/folders/yv/1k6t_v4x7798wpq87ddlnmjw0000gn/T/ipykernel_57289/2064102503.py:3: UserWarning: Parsing dates in %d/%m/%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df_incident['resolved_month'] = pd.to_datetime(df_incident['resolved_at']).dt.month
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[123], line 4
#       2 df_incident['opened_month'] = pd.to_datetime(df_incident['opened_at']).dt.month
#       3 df_incident['resolved_month'] = pd.to_datetime(df_incident['resolved_at']).dt.month
# ----> 4 df_incident['closed_month'] = pd.to_datetime(df_incident['closed_at']).dt.month
#       5 # Display the first few rows to confirm the conversion
#       6 df_incident[['opened_month', 'resolved_month', 'closed_month']].head()
#
# ...

# %%
# Out:
# 0         2403
# 1         2403
# 2         2403
# 3         2403
# 4         2403
#           ...
# 141707     116
# 141708     116
# 141709     116
# 141710     116
# 141711     116
# Name: caller_id, Length: 141712, dtype: int64

# %%
df_incident = df.drop(columns=['incident_state'])
df_incident = df.drop(columns=['number'])
